// %% [markdown]
// # Lab 15 Exercise 7

// %% [markdown]
// ## Prevent inheritance by keyword `sealed`

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab15_Ex07
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// Derived_2 d2 = new Derived_2();
// Base b = (Base) d2;
// Derived_1 d1 = (Derived_1) d2;
//
// b.A();
// d1.A();
// d2.A();
//
// class Base
// {
//     public virtual void A()
//     {
//         System.Console.WriteLine("Base.A()");
//     }
// }
// class Derived_1 : Base
// {
//     public sealed override void A()
//     {
//         System.Console.WriteLine("Derived_1.A()");
//     }
// }
// class Derived_2 : Derived_1
// {
//     public override void A()
//     {
//         System.Console.WriteLine("Derived_2.A()");
//     }
// }
// ```

// %%
Derived_2 d2 = new Derived_2();
Base b = (Base) d2;
Derived_1 d1 = (Derived_1) d2;

b.A();
d1.A();
d2.A();

class Base
{
    public virtual void A()
    {
        System.Console.WriteLine("Base.A()");
    }
}
class Derived_1 : Base
{
    public sealed override void A()
    {
        System.Console.WriteLine("Derived_1.A()");
    }
}
class Derived_2 : Derived_1
{
    public override void A()
    {
        System.Console.WriteLine("Derived_2.A()");
    }
}
// Out:
// (25,26): error CS0239: 'Derived_2.A()': cannot override inherited member 'Derived_1.A()' because it is sealed

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab15_Ex07
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
// ```cmd
// dotnet run --project Lab15_Ex07
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// 1. sealed ที่ใช้กับ คลาส: ป้องกันการสืบทอดจากคลาสนั้น
// 2. sealed ที่ใช้กับ เมธอด: ป้องกันการ override ในคลาสลูก
// 3. ถ้า Derived_1 ถูกปิดการสืบทอด (sealed), Derived_2 จะไม่สามารถสืบทอดจาก Derived_1 ได้ และจะเกิดข้อผิดพลาดตอนคอมไพล์
